# %%
import pandas as pd

# %%
slic_accuracies = pd.read_csv("/N/project/laidel_el_mcv/LAIDEL-MRI-tumor-id/results/metrics_csvs/slic_metrics.csv.csv")

# %%
slic_accuracies
# Out:
#                Unnamed: 0  True Positive  False negative  True Negative  \
# 0    BraTS20_Training_330       0.876252        0.123748       0.997857
# 1    BraTS20_Training_165       0.874109        0.125891       0.998114
# 2    BraTS20_Training_149       0.971982        0.028018       0.915735
# 3    BraTS20_Training_254       0.916746        0.083254       0.996783
# 4    BraTS20_Training_011       0.812897        0.187103       0.999448
# 5    BraTS20_Training_160       0.706225        0.293775       0.999678
# 6    BraTS20_Training_301       0.984874        0.015126       0.893338
# 7    BraTS20_Training_346       0.931780        0.068220       0.911523
# 8    BraTS20_Training_038       0.812052        0.187948       0.998133
# 9    BraTS20_Training_283       0.995758        0.004242       0.878018
# 10   BraTS20_Training_016       0.790060        0.209940       0.998660
# 11   BraTS20_Training_333       0.887936        0.112064       0.999491
# ...

# %%
kmeans_accuracies.mean()
# Out:
# True Positive                  0.878614
# False negative                 0.121386
# True Negative                  0.957245
# False positive                 0.042755
# Specificity                    0.501264
# Combined TP and Specificity    0.689939
# Dice Loss                      0.507967
# Jaccard Loss                   0.414287
# Total Error                    0.043902
# dtype: float64
