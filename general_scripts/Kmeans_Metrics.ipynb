# %%
import pandas as pd

# %%
kmeans_accuracies = pd.read_csv("/N/project/laidel_el_mcv/LAIDEL-MRI-tumor-id/results/metrics_csvs/kmeans_metrics.csv")

# %%
kmeans_accuracies
# Out:
#                Unnamed: 0  True Positive  False negative  True Negative  \
# 0    BraTS20_Training_330       0.804364        0.195636       0.999071
# 1    BraTS20_Training_165       0.814766        0.185234       0.998600
# 2    BraTS20_Training_149       0.796956        0.203044       0.983868
# 3    BraTS20_Training_254       0.866480        0.133520       0.996147
# 4    BraTS20_Training_011       0.813894        0.186106       0.998372
# 5    BraTS20_Training_160       0.660517        0.339483       0.999647
# 6    BraTS20_Training_301       0.897105        0.102895       0.972921
# 7    BraTS20_Training_346       0.867887        0.132113       0.983277
# 8    BraTS20_Training_038       0.690163        0.309837       0.997994
# 9    BraTS20_Training_283       0.966815        0.033185       0.972748
# 10   BraTS20_Training_016       0.696051        0.303949       0.999319
# 11   BraTS20_Training_333       0.856190        0.143810       0.999200
# ...

# %%
kmeans_accuracies.mean()
# Out:
# True Positive                  0.788965
# False negative                 0.211035
# True Negative                  0.974456
# False positive                 0.025544
# Specificity                    0.570427
# Combined TP and Specificity    0.679696
# Dice Loss                      0.558985
# Jaccard Loss                   0.438566
# Total Error                    0.027989
# dtype: float64
